# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# Import the dataset and take a look at the beginning of the data.
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Checking for missing data
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Changing df to suit my requirements.
df =df[['age','charges']]


# Using Scatterplot to Visualise Data
sns.scatterplot(data=df, x='age', y='charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Preparing the data for simple linear regression
X = df['age'].values.reshape(-1, 1)
y = df['charges'].values

# %%
# Creating and fitting the linear regression model
simple_model = LinearRegression()
simple_model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred = simple_model.predict(X)

# %%
sns.scatterplot(data=df, x='age', y='charges')
plt.plot(X, y_pred, color='red')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Linear Regression Best-fit Line')
plt.show()
